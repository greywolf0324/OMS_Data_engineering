# %%
import pandas as pd

df = pd.read_csv("output.csv")

for col in df:
    for item in df[col]:
        item = "asdf"
        # temp = str(item)
        
        # print(temp, type(temp))
        # if temp == "nan": item = ""
        # print(item)
        break
    break

        
df.head()
# Out:
#    RecordType* CustomerName*  InvoiceNumber*  Reference/Comment/Note  \
# 0          NaN      BUC-EE'S             NaN                     NaN
# 1          NaN      BUC-EE'S             NaN                     NaN
# 2          NaN      BUC-EE'S             NaN                     NaN
# 3          NaN      BUC-EE'S             NaN                     NaN
# 4          NaN      BUC-EE'S             NaN                     NaN
#
#    Product*  Quantity*  Price/Amount*  Discount  Tax  Total*  ...  \
# 0       NaN        NaN           46.8       0.0  NaN     NaN  ...
# 1       NaN        NaN           46.8       0.0  NaN     NaN  ...
# 2       NaN        NaN           93.6       0.0  NaN     NaN  ...
# 3       NaN        NaN           93.6       0.0  NaN     NaN  ...
# 4       NaN        NaN           93.6       0.0  NaN     NaN  ...
#
#    CustomField5 CustomField6  CustomField7  CustomField8  CustomField9  \
# 0           NaN          NaN           NaN           NaN           NaN
# ...
